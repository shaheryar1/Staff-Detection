# %%
import os

# %%
# %pwd
# Out:
# '/Users/memona/Desktop/Shaheryar/SAI/Staff-Detection/notebooks'

# %%
os.chdir('../')

# %%
os.listdir()
# Out:
# ['artifacts',
#  '.DS_Store',
#  'requirements.txt',
#  'config',
#  'params.yaml',
#  'README.md',
#  'setup.py',
#  'dvc.yaml',
#  'logs',
#  'run_streamlit_app.py',
#  '.gitignore',
#  '.github',
#  'template.py',
#  'templates',
#  'venv',
#  '.git',
#  'main.py',
#  'notebooks',
#  'src']

# %%
from staffClassifier import logger
from staffClassifier.config_manager.configuration import ConfigurationManager
from staffClassifier.components.models import get_custom_model

# %%
m = ConfigurationManager().get_model_config()
model = get_custom_model(m)
logger.info(model)
# Out:
# [2024-04-07 22:57:54,861: INFO: common: yaml file: config/config.yaml loaded successfully]
# [2024-04-07 22:57:54,864: INFO: common: yaml file: params.yaml loaded successfully]
# [2024-04-07 22:57:54,865: INFO: common: created directory at: artifacts]
# [2024-04-07 22:57:55,035: INFO: 3082623856: MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
# ...
